# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import sys
import math
import scipy

# %% [markdown]
# ## $\Phi$定義

# %%
#eq.3.3
def Phi(x, mu, sigma):
  return np.exp(?? / ??)

# %% [markdown]
# ## $\boldsymbol{x}, \boldsymbol{\mu},\sigma$

# %%
X = np.arange(-4-3, 5+3, 0.1)
Mu = np.arange(-4, 4, 1)
sigma = 1

# %% [markdown]
# ##計算

# %%
Y = np.zeros((len(Mu),len(X)))
for i in range(0,len(Mu)):
  for j in range(0,len(X)):
    Y[i][j] = Phi(X[j], Mu[i], sigma)

# %% [markdown]
# ## plot

# %%
plt.figure()
for n in range(len(Y)):
  plt.plot(X, Y[n])
plt.show()

# %% [markdown]
# # $\mu$に対応する$w$

# %%
W = np.array([-0.48, -0.64, 0.41, 0.28, 0.57, 0.50, -0.26, 0.60]) 
#W = [np.random.randn() for i in range(len(Mu))]

# %% [markdown]
# ## 計算

# %%
Y_2 = np.zeros((len(Mu),len(X)))
for i in range(0,len(Mu)):
  for j in range(0,len(X)):
    Y_2[i][j] = Phi(X[j], Mu[i], sigma) * ??
Y_2_sum = Y_2.sum(axis=0)

# %% [markdown]
# ## plot

# %%
plt.figure()
plt.plot(X, Y_2_sum)
plt.show()

# %% [markdown]
# ## ここから、$+\alpha$
# ### 2dim

# %% [markdown]
# ## $\boldsymbol{x}, \boldsymbol{\mu},\sigma$

# %%
X = np.arange(-2-5,3+5,1)
Mu = np.arange(-2,3,1)
W = np.array([np.random.randn() for mu1 in Mu for mu2 in Mu]) #mu^(2), 2次元なので...

# %% [markdown]
# ## 計算

# %%
#eq. 2.18
def Log_gauss_multi (x):
  D = len(x)
  log_p = - np.log (??) * D / 2 - np.dot(??,??) / 2
  return log_p

# %%
Y = []
n = 0
for mu1 in Mu:
  for mu2 in Mu:
    y = []
    for x1 in X:
      for x2 in X:
        yy = np.exp(Log_gauss_multi([??-??, ??-??])) * ??
        y.append(yy)
    y = np.array(y).reshape(len(X), len(X))
    Y.append(y)
    n += 1

# %% [markdown]
# ## 25個plot

# %%
x1,x2 = np.meshgrid (X,X)

for h in range(len(Y)):
  ax = Axes3D(plt.figure())
  ax.tick_params(labelsize = 8)
  ax.set_xlabel ('x_1')
  ax.set_ylabel ('x_2')
  ax.plot_surface (??, ??, ??[h], shade=False,linewidth=0.3,edgecolor='black', color='b')
  plt.show()

# %% [markdown]
# ## 25個のyのsumをplot

# %%
x1,x2 = np.meshgrid (X,X)
#sum
YY = np.sum(??, axis=0)


ax = Axes3D(plt.figure())
ax.tick_params(labelsize = 8)
ax.set_xlabel ('x_1')
ax.set_ylabel ('x_2')
ax.set_zlabel (r'$N( x | 0, I)$')
ax.plot_surface (??, ??, ??,shade=False,linewidth=0.3,edgecolor='black', color='b')
plt.show()

# %% [markdown]
# # ガウス過程からのサンプル

# %% [markdown]
# ### カーネル定義

# %%
def RBF(theta1, theta2, x,x_d):
  return ??

# %% [markdown]
# ### パラメータ等

# %%
xx = np.arange(1, 5)
theta1 = 1.0
theta2 = 1.0

# %% [markdown]
# ### カーネル行列計算

# %%
K = np.zeros((len(xx), len(xx)))
for i in range(len(xx)):
  for j in range(len(xx)):
    k = RBF(theta1, theta2, ??[i], ??[j])
    K[i][j]=k

# %% [markdown]
# ### サンプル

# %%
#2.3.2
#コレスキー
L = np.linalg.cholesky( ?? )

N = 1
Y = []
for n in range(N):
  x = np.random.randn(len(K[0]))
  y = np.dot(??, ??)
  Y.append(y)

# %% [markdown]
# ### plot

# %%
plt.figure()
plt.xlabel('xx')
plt.ylabel('y')


plt.plot (??, ??, 'ob', markersize=4)
plt.show()

# %% [markdown]
# ## ver2

# %%
xx = np.arange(1,5, 0.2)

# %%
KK = np.zeros((len(xx), len(xx)))
for i in range(len(xx)):
  for j in range(len(xx)):
    k = RBF(theta1, theta2, ??[i], ??[j])
    KK[i][j]=k

# %%
#2.3.2
#コレスキー
L = np.linalg.cholesky( ?? )

N = 1
Y = []
for n in range(N):
  x = np.random.randn(len(KK[0]))
  y = np.dot(??, ??)
  Y.append(y)

# %% [markdown]
# ### plot

# %%
plt.figure()
plt.xlabel('xx')
plt.ylabel('y')


plt.plot (??, ??, 'ob', markersize=4)
plt.show()
